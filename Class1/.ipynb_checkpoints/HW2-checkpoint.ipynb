# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("./loans_income.csv")

# %%
df.shape
# Out:
# (50000, 1)

# %%
df.describe()
# Out:
#                   x
# count   50000.00000
# mean    68760.51844
# std     32872.03537
# min      4000.00000
# 25%     45000.00000
# 50%     62000.00000
# 75%     85000.00000
# max    199000.00000

# %%
df.plot(kind="hist",figsize=(20,10))

# %%
df1000 = df.sample(n=1000)

# %%
df1000.describe()
# Out:
#                    x
# count    1000.000000
# mean    68296.228000
# std     32790.197811
# min     10000.000000
# 25%     45000.000000
# 50%     61000.000000
# 75%     85000.000000
# max    192000.000000

# %%
df1000.plot(kind="hist",figsize=(20,10))

# %%
sample10_10 = []
for i in range(10):
    sample10_10 += df.sample(n=10,replace=True)["x"].tolist()

# %%
sample10_50 = []
for i in range(50):
    sample10_50 += df.sample(n=10,replace=True)["x"].tolist()

# %%
sample10_100 = []
for i in range(100):
    sample10_100 += df.sample(n=10,replace=True)["x"].tolist()

# %%
sample10_1000 = []
for i in range(1000):
    sample10_1000 += df.sample(n=10,replace=True)["x"].tolist()

# %%
dfplot = pd.DataFrame(sample10_10)
# %matplotlib inline
dfplot.plot(kind="hist",figsize=(20,10))

# %%
dfplot = pd.DataFrame(sample10_50)
# %matplotlib inline
dfplot.plot(kind="hist",figsize=(20,10))

# %%
dfplot = pd.DataFrame(sample10_100)
# %matplotlib inline
dfplot.plot(kind="hist",figsize=(20,10))

# %%
dfplot = pd.DataFrame(sample10_1000)
# %matplotlib inline
dfplot.plot(kind="hist",figsize=(20,10))

# %%
sample100_10 = []
for i in range(10):
    sample100_10 += df.sample(n=100,replace=True)["x"].tolist()

sample100_50 = []
for i in range(50):
    sample100_50 += df.sample(n=100,replace=True)["x"].tolist()

sample100_100 = []
for i in range(100):
    sample100_100 += df.sample(n=100,replace=True)["x"].tolist()
    
sample100_1000 = []
for i in range(1000):
    sample100_1000 += df.sample(n=100,replace=True)["x"].tolist()

# %%
dfplot = pd.DataFrame(sample100_10)
# %matplotlib inline
dfplot.plot(kind="hist",figsize=(20,10))

# %%
dfplot = pd.DataFrame(sample100_50)
# %matplotlib inline
dfplot.plot(kind="hist",figsize=(20,10))

# %%
dfplot = pd.DataFrame(sample100_100)
# %matplotlib inline
dfplot.plot(kind="hist",figsize=(20,10))

# %%
dfplot = pd.DataFrame(sample100_1000)
# %matplotlib inline
dfplot.plot(kind="hist",figsize=(20,10))
